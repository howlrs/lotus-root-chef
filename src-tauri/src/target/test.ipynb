# %%
import pandas as pd

# %%
data = [97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97450.0, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97458.8, 97461.8, 97461.8, 97465.9, 97465.9, 97465.9, 97465.9, 97465.9, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3, 97469.3]

# %%
df = pd.DataFrame(data, columns=['data'])

# %%
df.plot()
# Out:
# <Axes: >
